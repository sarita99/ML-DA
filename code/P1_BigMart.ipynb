# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data/ds_infosys/BigMart.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           DRA12         11.6          Low Fat         0.041178  Soft Drinks
# 1           DRA12         11.6          Low Fat         0.000000  Soft Drinks
# 2           DRA12         11.6          Low Fat         0.040912  Soft Drinks
# 3           DRA12         11.6               LF         0.000000  Soft Drinks
# 4           DRA12         11.6          Low Fat         0.041113  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  140.3154            OUT017                       2007         NaN
# 1  141.6154            OUT045                       2002         NaN
# 2  142.3154            OUT013                       1987        High
# 3  141.9154            OUT035                       2004       Small
# 4  142.0154            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           NCZ54        14.65          Low Fat         0.083528
# 8519           NCZ54        14.65          Low Fat         0.083359
# 8520           NCZ54          NaN          Low Fat         0.145952
# 8521           NCZ54        14.65          Low Fat         0.083699
# 8522           NCZ54        14.65          Low Fat         0.083489
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8518  Household  162.4552            OUT045                       2002
# 8519  Household  161.9552            OUT046                       1997
# 8520  Household  160.9552            OUT019                       1985
# 8521  Household  163.4552            OUT018                       2009
# 8522  Household  161.3552            OUT049                       1999
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Identifier'].value_counts().sort_values()
# Out:
# OUT019    528
# OUT010    555
# OUT017    926
# OUT018    928
# OUT045    929
# OUT035    930
# OUT049    930
# OUT046    930
# OUT013    932
# OUT027    935
# Name: Outlet_Identifier, dtype: int64

# %%
df.groupby(by='Outlet_Identifier').count()['Outlet_Size'].sort_values()
##3 outlets have no size. lets remove it.
# Out:
# Outlet_Identifier
# OUT010      0
# OUT017      0
# OUT045      0
# OUT019    528
# OUT018    928
# OUT035    930
# OUT046    930
# OUT049    930
# OUT013    932
# OUT027    935
# Name: Outlet_Size, dtype: int64

# %%
df.drop()

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
df[df['Item_Weight'].isnull()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              DRA24          NaN          Regular         0.069909
# 9              DRA24          NaN          Regular         0.039735
# 17             DRA59          NaN          Regular         0.127308
# 18             DRA59          NaN          Regular         0.223985
# 23             DRB01          NaN          Low Fat         0.081841
# ...              ...          ...              ...              ...
# 8486           NCZ18          NaN          Low Fat         0.325781
# 8499           NCZ30          NaN               LF         0.026058
# 8512           NCZ53          NaN          Low Fat         0.024359
# 8517           NCZ54          NaN          Low Fat         0.082956
# 8520           NCZ54          NaN          Low Fat         0.145952
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 7            Soft Drinks  163.2868            OUT019
# ...

# %%
df[df['Item_Identifier']=='FDP10']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4016           FDP10          NaN          Low Fat         0.127470
# 4017           FDP10         19.0          Low Fat         0.128066
# 4018           FDP10         19.0          Low Fat         0.128815
# 4019           FDP10         19.0          Low Fat         0.128289
# 4020           FDP10         19.0          Low Fat         0.128090
# 4021           FDP10         19.0          Low Fat         0.128350
# 4022           FDP10         19.0          Low Fat         0.127984
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 4016  Snack Foods  107.7622            OUT027                       1985
# 4017  Snack Foods  104.3622            OUT035                       2004
# 4018  Snack Foods  107.6622            OUT017                       2007
# 4019  Snack Foods  104.9622            OUT049                       1999
# ...

# %%
df[df['Item_Identifier']=='DRI11']
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 435           DRI11          NaN          Low Fat         0.034238
# 436           DRI11          NaN          Low Fat         0.060237
# 437           DRI11         8.26          Low Fat         0.034458
# 438           DRI11         8.26          Low Fat         0.057586
# 439           DRI11         8.26          Low Fat         0.034398
# 440           DRI11         8.26          Low Fat         0.034544
# 441           DRI11         8.26          Low Fat         0.034474
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 435  Hard Drinks  113.2834            OUT027                       1985
# 436  Hard Drinks  115.9834            OUT019                       1985
# 437  Hard Drinks  113.3834            OUT049                       1999
# 438  Hard Drinks  113.7834            OUT010                       1998
# ...

# %%
#to replace nan item_weights with corresponding weights from other rows
item_attrs = df[['Item_Identifier','Item_Weight']].dropna().drop_duplicates()
new_df = df[['Item_Identifier']].merge(item_attrs,'left')
new_df
# Out:
#      Item_Identifier  Item_Weight
# 0              DRA12        11.60
# 1              DRA12        11.60
# 2              DRA12        11.60
# 3              DRA12        11.60
# 4              DRA12        11.60
# ...              ...          ...
# 8518           NCZ54        14.65
# 8519           NCZ54        14.65
# 8520           NCZ54        14.65
# 8521           NCZ54        14.65
# 8522           NCZ54        14.65
#
# [8523 rows x 2 columns]

# %%
df = df.drop(['Item_Weight'],axis = 1)
df
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0              DRA12          Low Fat         0.041178  Soft Drinks  140.3154
# 1              DRA12          Low Fat         0.000000  Soft Drinks  141.6154
# 2              DRA12          Low Fat         0.040912  Soft Drinks  142.3154
# 3              DRA12               LF         0.000000  Soft Drinks  141.9154
# 4              DRA12          Low Fat         0.041113  Soft Drinks  142.0154
# ...              ...              ...              ...          ...       ...
# 8518           NCZ54          Low Fat         0.083528    Household  162.4552
# 8519           NCZ54          Low Fat         0.083359    Household  161.9552
# 8520           NCZ54          Low Fat         0.145952    Household  160.9552
# 8521           NCZ54          Low Fat         0.083699    Household  163.4552
# 8522           NCZ54          Low Fat         0.083489    Household  161.3552
#
# ...

# %%
df.insert(1,'Item_Weight',new_df['Item_Weight'],True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              DRA12        11.60          Low Fat         0.041178
# 1              DRA12        11.60          Low Fat         0.000000
# 2              DRA12        11.60          Low Fat         0.040912
# 3              DRA12        11.60               LF         0.000000
# 4              DRA12        11.60          Low Fat         0.041113
# ...              ...          ...              ...              ...
# 8518           NCZ54        14.65          Low Fat         0.083528
# 8519           NCZ54        14.65          Low Fat         0.083359
# 8520           NCZ54        14.65          Low Fat         0.145952
# 8521           NCZ54        14.65          Low Fat         0.083699
# 8522           NCZ54        14.65          Low Fat         0.083489
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Soft Drinks  140.3154            OUT017                       2007
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     4
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df[df['Item_Weight'].isna()]#4 items have null weight
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1901           FDE52          NaN          Regular         0.029742
# 3152           FDK57          NaN          Low Fat         0.079904
# 3724           FDN52          NaN          Regular         0.130933
# 4454           FDQ60          NaN          Regular         0.191501
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 1901         Dairy   88.9514            OUT027                       1985
# 3152   Snack Foods  120.0440            OUT027                       1985
# 3724  Frozen Foods   86.9198            OUT027                       1985
# 4454  Baking Goods  121.2098            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 1901      Medium               Tier 3  Supermarket Type3          3453.5046
# 3152      Medium               Tier 3  Supermarket Type3          4434.2280
# ...

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'LF', 'Regular', 'reg', 'low fat'], dtype=object)

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace(['low fat','LF','reg'],['Low Fat','Low Fat','Regular'])
#replace the values correctly

# %%
df['Item_Type'].unique()
# Out:
# array(['Soft Drinks', 'Dairy', 'Hard Drinks', 'Canned', 'Frozen Foods',
#        'Fruits and Vegetables', 'Snack Foods', 'Baking Goods',
#        'Starchy Foods', 'Meat', 'Seafood', 'Breakfast', 'Breads',
#        'Health and Hygiene', 'Household', 'Others'], dtype=object)

# %%
df['Outlet_Size'].unique()
# Out:
# array([nan, 'High', 'Small', 'Medium'], dtype=object)

# %%
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 2', 'Tier 3', 'Tier 1'], dtype=object)

# %%
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
#convert object to category type for the categorical features
df['Outlet_Type'] = df['Outlet_Type'].astype('category')
df['Outlet_Location_Type'] = df['Outlet_Location_Type'].astype('category')
df['Item_Type'] = df['Item_Type'].astype('category')
df['Item_Fat_Content'] = df['Item_Fat_Content'].astype('category')
df['Outlet_Size'] = df['Outlet_Size'].astype('category')

# %%
#select features and target variables
X = [:11,axis=1]
y = ['Item_Outlet_Sales']

# %% [markdown]
# first split data into train and test
# then apply encoding to prevent data leakage

# %%
#split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 10, train_size = 0.8, shuffle=True)

# %%
#one hot encode the categorical columns
ohe = pd.get_dummies(data = df,columns = ['Item_Type','Item_Fat_Content','Outlet_Type','Outlet_Location_Type'])
ohe1 = pd.get_dummies(data = ohe,columns = ['Outlet_Size'],dummy_na=True)

# %%
ohe1
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0              DRA12        11.60         0.041178  140.3154
# 1              DRA12        11.60         0.000000  141.6154
# 2              DRA12        11.60         0.040912  142.3154
# 3              DRA12        11.60         0.000000  141.9154
# 4              DRA12        11.60         0.041113  142.0154
# ...              ...          ...              ...       ...
# 8518           NCZ54        14.65         0.083528  162.4552
# 8519           NCZ54        14.65         0.083359  161.9552
# 8520           NCZ54        14.65         0.145952  160.9552
# 8521           NCZ54        14.65         0.083699  163.4552
# 8522           NCZ54        14.65         0.083489  161.3552
#
#      Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0               OUT017                       2007          2552.6772
# 1               OUT045                       2002          3829.0158
# ...

# %%
finaldf = ohe1.drop(['Item_Outlet_Sales'],axis=1)

# %%
finaldf['Item_Outlet_Sales'] = ohe1['Item_Outlet_Sales'].values#add the target variable at the end of df
finaldf
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0              DRA12        11.60         0.041178  140.3154
# 1              DRA12        11.60         0.000000  141.6154
# 2              DRA12        11.60         0.040912  142.3154
# 3              DRA12        11.60         0.000000  141.9154
# 4              DRA12        11.60         0.041113  142.0154
# ...              ...          ...              ...       ...
# 8518           NCZ54        14.65         0.083528  162.4552
# 8519           NCZ54        14.65         0.083359  161.9552
# 8520           NCZ54        14.65         0.145952  160.9552
# 8521           NCZ54        14.65         0.083699  163.4552
# 8522           NCZ54        14.65         0.083489  161.3552
#
#      Outlet_Identifier  Outlet_Establishment_Year  Item_Type_Baking Goods  \
# 0               OUT017                       2007                       0
# 1               OUT045                       2002                       0
# ...
