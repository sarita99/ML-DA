# %%
import pandas as pd

# %%
df_orders = pd.read_csv('data/superstore.csv')
df_orders
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df_orders.drop('Row ID', axis=1,inplace=True)

# %%
df_orders
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df_orders.shape
# Out:
# (9994, 20)

# %%
df_orders.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_orders.dtypes
# Out:
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df_orders = pd.read_csv('data/superstore.csv', index_col = 'Order ID')
df_orders
# Out:
#                 Row ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2016-152156       1   11/8/2016  11/11/2016    Second Class    CG-12520
# CA-2016-152156       2   11/8/2016  11/11/2016    Second Class    CG-12520
# CA-2016-138688       3   6/12/2016   6/16/2016    Second Class    DV-13045
# US-2015-108966       4  10/11/2015  10/18/2015  Standard Class    SO-20335
# US-2015-108966       5  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# CA-2014-110422    9990   1/21/2014   1/23/2014    Second Class    TB-21400
# CA-2017-121258    9991   2/26/2017    3/3/2017  Standard Class    DB-13060
# CA-2017-121258    9992   2/26/2017    3/3/2017  Standard Class    DB-13060
# CA-2017-121258    9993   2/26/2017    3/3/2017  Standard Class    DB-13060
# CA-2017-119914    9994    5/4/2017    5/9/2017    Second Class    CC-12220
#
# ...

# %%
df_orders = pd.read_csv('data/superstore.csv', index_col='Order ID')
df_orders.drop("Row ID", axis=1, inplace=True)
df_orders
# Out:
#                 Order Date   Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...                    ...         ...             ...         ...
# CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#                    Customer Name    Segment        Country             City  \
# Order ID
# ...

# %%
df_orders.shape
# Out:
# (9994, 19)

# %%
df_orders.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_orders.columns = ['OrderDate', 'ShipDate', 'ShipMode', 'CustomerID', 'CustomerName', 'Segment' , 'Country', 'City', 'State', 'PostalCode', 'Region', 'ProductID', 'Category', 'SubCategory', 'ProductName' , 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
df_orders.columns
# Out:
# Index(['OrderDate', 'ShipDate', 'ShipMode', 'CustomerID', 'CustomerName',
#        'Segment', 'Country', 'City', 'State', 'PostalCode', 'Region',
#        'ProductID', 'Category', 'SubCategory', 'ProductName', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, CA-2016-152156 to CA-2017-119914
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderDate     9994 non-null   object
#  1   ShipDate      9994 non-null   object
#  2   ShipMode      9994 non-null   object
#  3   CustomerID    9994 non-null   object
#  4   CustomerName  9994 non-null   object
#  5   Segment       9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   State         9994 non-null   object
#  9   PostalCode    9994 non-null   int64
#  10  Region        9994 non-null   object
#  11  ProductID     9994 non-null   object
#  12  Category      9994 non-null   object
#  13  SubCategory   9994 non-null   object
#  14  ProductName   9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
# ...

# %%
df_orders['OrderDate'] = df_orders['OrderDate'].astype('datetime64[ns]')
df_orders['ShipDate'] = df_orders['ShipDate'].astype('datetime64[ns]')
df_orders['PostalCode'] = df_orders['PostalCode'].astype('object')

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, CA-2016-152156 to CA-2017-119914
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderDate     9994 non-null   datetime64[ns]
#  1   ShipDate      9994 non-null   datetime64[ns]
#  2   ShipMode      9994 non-null   object
#  3   CustomerID    9994 non-null   object
#  4   CustomerName  9994 non-null   object
#  5   Segment       9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   State         9994 non-null   object
#  9   PostalCode    9994 non-null   object
#  10  Region        9994 non-null   object
#  11  ProductID     9994 non-null   object
#  12  Category      9994 non-null   object
#  13  SubCategory   9994 non-null   object
#  14  ProductName   9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
# ...

# %%
df_orders.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df_orders.describe(include = 'all')
# Out:
# <ipython-input-18-4cd4b33bcb2f>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_orders.describe(include = 'all')
# <ipython-input-18-4cd4b33bcb2f>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_orders.describe(include = 'all')
#                   OrderDate             ShipDate        ShipMode CustomerID  \
# count                  9994                 9994            9994       9994
# unique                 1237                 1334               4        793
# top     2016-09-05 00:00:00  2015-12-16 00:00:00  Standard Class   WB-21850
# ...

# %%
df_orders.to_csv('data/superstore_export1.csv',index=False)#index col is not saved to csv file

# %%
def display_all(df_orders):
    with pd.option_context("display.max_rows", 100, "display.max_columns", 100):
        display(df_orders)

# %%
display_all(df_orders.head(10)) #display_all(df_orders.head(10).T)> transposes the table
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
#
#                    CustomerName    Segment        Country             City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# ...

# %%
display_all(df_orders.describe(include='all').T)
# Out:
# <ipython-input-22-a43885adadb7>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display_all(df_orders.describe(include='all').T)
# <ipython-input-22-a43885adadb7>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display_all(df_orders.describe(include='all').T)
#                count unique                  top   freq      first       last  \
# OrderDate       9994   1237  2016-09-05 00:00:00     38 2014-01-03 2017-12-30
# ShipDate        9994   1334  2015-12-16 00:00:00     35 2014-01-07 2018-01-05
# ShipMode        9994      4       Standard Class   5968        NaT        NaT
# ...

# %%
display_all(df_orders)
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# ...                   ...        ...             ...        ...
# CA-2014-110422 2014-01-21 2014-01-23    Second Class   TB-21400
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
# CA-2017-119914 2017-05-04 2017-05-09    Second Class   CC-12220
#
#                     CustomerName    Segment        Country             City  \
# Order ID
# CA-2016-152156       Claire Gute   Consumer  United States        Henderson
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df_orders['CustomerName'],df_orders['Sales'])
plt.title('Scatter plot')
plt.xlabel('Customer')
plt.ylabel('Sales')
plt.show()#not good plot

# %%
dx = df_orders.groupby(['CustomerName'])['Sales'].agg(TotalSales=sum).reset_index()
dx
# Out:
#            CustomerName  TotalSales
# 0         Aaron Bergman     886.156
# 1         Aaron Hawkins    1744.700
# 2        Aaron Smayling    3050.692
# 3       Adam Bellavance    7755.620
# 4             Adam Hart    3250.337
# ..                  ...         ...
# 788        Xylona Preis    2374.658
# 789       Yana Sorensen    6720.444
# 790      Yoseph Carroll    5454.350
# 791    Zuschuss Carroll    8025.707
# 792  Zuschuss Donatelli    1493.944
#
# [793 rows x 2 columns]
