# %%
import pandas as pd
df = pd.read_excel('data/netflix_titles.xlsx')
df
# Out:
#      duration_minutes duration_seasons     type  \
# 0                  90              NaN    Movie
# 1                  94              NaN    Movie
# 2                 NaN                1  TV Show
# 3                 NaN                1  TV Show
# 4                  99              NaN    Movie
# ...               ...              ...      ...
# 6231              NaN               13  TV Show
# 6232              NaN                4  TV Show
# 6233               60              NaN    Movie
# 6234              NaN                2  TV Show
# 6235              NaN               10  TV Show
#
#                                             title           date_added  \
# 0         Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1                      Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2                              Transformers Prime  2018-09-08 00:00:00
# 3                Transformers: Robots in Disguise  2018-09-08 00:00:00
# ...

# %%
df.columns
# Out:
# Index(['duration_minutes', 'duration_seasons', 'type', 'title', 'date_added',
#        'release_year', 'rating', 'description', 'show_id'],
#       dtype='object')

# %%
df.shape
# Out:
# (6236, 9)

# %%
df.dtypes
# Out:
# duration_minutes     object
# duration_seasons     object
# type                 object
# title                object
# date_added           object
# release_year        float64
# rating               object
# description          object
# show_id             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   duration_minutes  4267 non-null   object
#  1   duration_seasons  1971 non-null   object
#  2   type              6235 non-null   object
#  3   title             6235 non-null   object
#  4   date_added        6223 non-null   object
#  5   release_year      6234 non-null   float64
#  6   rating            6223 non-null   object
#  7   description       6233 non-null   object
#  8   show_id           6232 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 438.6+ KB

# %%
df['release_year'] = df['release_year'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-5837387ba89d> in <module>
# ----> 1 df['release_year'] = df['release_year'].astype('int64')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df['date_added'] = df['date_added'].astype('datetime64[ns]')

# %%
df.isnull().sum()
# Out:
# duration_minutes    1969
# duration_seasons    4265
# type                   1
# title                  1
# date_added            13
# release_year           2
# rating                13
# description            3
# show_id                4
# dtype: int64

# %%
df.isna().sum()
# Out:
# duration_minutes    1969
# duration_seasons    4265
# type                   1
# title                  1
# date_added            13
# release_year           2
# rating                13
# description            3
# show_id                4
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      duration_minutes duration_seasons     type  \
# 0                  90              NaN    Movie
# 1                  94              NaN    Movie
# 2                 NaN                1  TV Show
# 3                 NaN                1  TV Show
# 4                  99              NaN    Movie
# ...               ...              ...      ...
# 6231              NaN               13  TV Show
# 6232              NaN                4  TV Show
# 6233               60              NaN    Movie
# 6234              NaN                2  TV Show
# 6235              NaN               10  TV Show
#
#                                             title           date_added  \
# 0         Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1                      Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2                              Transformers Prime  2018-09-08 00:00:00
# 3                Transformers: Robots in Disguise  2018-09-08 00:00:00
# ...

# %%
print(df['type'].unique())
# Out:
# ['Movie' 'TV Show' 1944 nan]

# %%
df[df['type'].isnull()] ##garbage record
# Out:
#           duration_minutes duration_seasons type title date_added  \
# 4525   and probably will."         80188902  NaN   NaN        NaN
#
#       release_year rating description  show_id
# 4525           NaN    NaN         NaN      NaN

# %%
df[df['title'].isnull()]
# Out:
#           duration_minutes duration_seasons type title date_added  \
# 4525   and probably will."         80188902  NaN   NaN        NaN
#
#       release_year rating description  show_id
# 4525           NaN    NaN         NaN      NaN

# %%
df[df['show_id'].isnull()]
# Out:
#           duration_minutes     duration_seasons   type  \
# 2017                    40                  NaN  Movie
# 2018      Flying Fortress"  2017-03-31 00:00:00   1944
# 4524                    87                  NaN  Movie
# 4525   and probably will."             80188902    NaN
#
#                                 title  \
# 2017  The Memphis Belle: A Story of a
# 2018                            TV-PG
# 4524          The Bad Education Movie
# 4525                              NaN
#
#                                              date_added  release_year rating  \
# 2017                                                NaN           NaN    NaN
# 2018  This documentary centers on the crew of the B-...    80119194.0    NaN
# 4524                                2018-12-15 00:00:00        2015.0  TV-MA
# 4525                                                NaN           NaN    NaN
#
#                                             description  show_id
# ...
